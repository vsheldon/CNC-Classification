# %%
import numpy as np
import matplotlib.pyplot as plt

if __name__ == '__main__':
	
	S1 = np.loadtxt('S1.txt')[2000:-1,:]
	X1 = np.loadtxt('X1.txt')[2000:-1,:]
	Y1 = np.loadtxt('Y1.txt')[2000:-1,:]
	Z1 = np.loadtxt('Z1.txt')[2000:-1,:]

# %%
plt.plot(Y1[:,0],'r-',Y1[:,3],'b--')
plt.show()
#position

# %%
plt.plot(Z1[:,1],'r-',Z1[:,4],'b--')
plt.show()
#speed

# %%
plt.plot(X1[:,2],'r-',X1[:,5],'b--')
plt.show()
#acceleration

# %%
plt.plot(X1[:,6],'r.',Y1[:,6],'b.',Z1[:,6],'k.')
plt.show()
#current feedback

# %%
plt.plot(Z1[:,9])
plt.show()
#DCBusVoltage

# %%
plt.plot(X1[:,8])
plt.show()
#Output current

# %%
plt.plot(X1[:,9])
plt.show()
#Output voltage

# %%
plt.plot(X1[:,10])
plt.show()
#Output power

# %%
plt.plot(Y1[:,2],'r-',Y1[:,5],'b--')
plt.show()
#acceleration

# %%
plt.plot(Z1[:,2],'r-',Z1[:,5],'b--')
plt.show()
#acceleration

# %%
Z1[1:5000,0:9] == X1[1:5000,0:9]
# Out:
# array([[False,  True, False, ..., False, False, False],
#        [False,  True, False, ..., False, False, False],
#        [False,  True, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]], dtype=bool)

# %%
plt.plot(S1[:,10])
plt.show()

# %%
plt.plot(S1[:,11])
plt.show()

# %%
X = np.fft.fft(X1)
freq = np.fft.fftfreq(X1.shape[0])
plt.plot(freq,X.real,freq,X.imag)
plt.show()

# %%
plt.plot(freq,X[:,10].real,freq,X[:,10].imag)
plt.show()
